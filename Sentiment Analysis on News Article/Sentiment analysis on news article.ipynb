# %%
# Dependencies
import tweepy
import json
import numpy as np
import time
import pandas as pd
import time
from matplotlib import pyplot as plt
import seaborn as sns
import csv
import os

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys 
consumer_key = 'sh+'
consumer_secret = '+ad+' 
access_token = '+a+'
access_token_secret = '+ab Ahmd'

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Search Term
target_terms = ("@BBCNews", "@CBSNews", "@CNN", "@FoxNews", "@nytimes","@TimesofIndia")

# %%
# List for tweet data
data = []
# Loop through all targets
for target in target_terms:
    counter=101
    public_tweets = api.user_timeline(target, count=1200, result_type="recent")
#     tweetstorage[target]= public_tweets
    for tweet in public_tweets:

        # Run VAnalysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweetorder=counter-1
        counter=counter-1
        #Temp store other values
        date=time.strftime('%m/%d/%Y', time.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
        text=(tweet["text"])
        name=(tweet["user"]["name"])

        #append value to DataFrame
        data.append({"Media Sources":name,"Tweet Polarity":compound,"Positive":pos,"Neutral":neu,
                          "Date":date,"Text":text, "Tweets Order":tweetorder})

# %%
data=pd.DataFrame(data)
data
# Out:
#             Date   Media Sources  Neutral  Positive  \
# 0     12/15/2019   BBC News (UK)    1.000     0.000
# 1     12/15/2019   BBC News (UK)    0.759     0.241
# 2     12/15/2019   BBC News (UK)    0.678     0.227
# 3     12/15/2019   BBC News (UK)    0.906     0.000
# 4     12/15/2019   BBC News (UK)    0.574     0.426
# 5     12/15/2019   BBC News (UK)    1.000     0.000
# 6     12/15/2019   BBC News (UK)    0.807     0.000
# 7     12/15/2019   BBC News (UK)    0.758     0.242
# 8     12/15/2019   BBC News (UK)    1.000     0.000
# 9     12/15/2019   BBC News (UK)    0.856     0.000
# 10    12/15/2019   BBC News (UK)    0.777     0.000
# 11    12/15/2019   BBC News (UK)    0.901     0.000
# 12    12/15/2019   BBC News (UK)    1.000     0.000
# 13    12/15/2019   BBC News (UK)    0.804     0.000
# 14    12/15/2019   BBC News (UK)    0.650     0.350
# 15    12/15/2019   BBC News (UK)    1.000     0.000
# 16    12/15/2019   BBC News (UK)    0.634     0.194
# 17    12/15/2019   BBC News (UK)    1.000     0.000
# 18    12/15/2019   BBC News (UK)    1.000     0.000
# 19    12/15/2019   BBC News (UK)    1.000     0.000
# 20    12/15/2019   BBC News (UK)    0.743     0.257
# 21    12/15/2019   BBC News (UK)    0.559     0.000
# 22    12/15/2019   BBC News (UK)    0.809     0.000
# 23    12/15/2019   BBC News (UK)    1.000     0.000
# 24    12/15/2019   BBC News (UK)    0.717     0.283
# 25    12/15/2019   BBC News (UK)    0.857     0.000
# 26    12/15/2019   BBC News (UK)    0.871     0.000
# 27    12/15/2019   BBC News (UK)    1.000     0.000
# 28    12/15/2019   BBC News (UK)    1.000     0.000
# 29    12/15/2019   BBC News (UK)    0.766     0.000
# ...          ...             ...      ...       ...
# 1170  12/15/2019  Times of India    0.758     0.242
# 1171  12/15/2019  Times of India    0.858     0.142
# 1172  12/15/2019  Times of India    0.662     0.000
# 1173  12/15/2019  Times of India    0.826     0.174
# 1174  12/15/2019  Times of India    0.822     0.000
# 1175  12/15/2019  Times of India    0.909     0.091
# 1176  12/15/2019  Times of India    0.718     0.282
# 1177  12/15/2019  Times of India    1.000     0.000
# 1178  12/15/2019  Times of India    1.000     0.000
# 1179  12/15/2019  Times of India    1.000     0.000
# 1180  12/15/2019  Times of India    0.816     0.184
# 1181  12/15/2019  Times of India    0.765     0.235
# 1182  12/15/2019  Times of India    0.724     0.000
# 1183  12/15/2019  Times of India    1.000     0.000
# 1184  12/15/2019  Times of India    0.851     0.000
# 1185  12/15/2019  Times of India    0.596     0.000
# 1186  12/15/2019  Times of India    0.852     0.148
# 1187  12/15/2019  Times of India    0.817     0.183
# 1188  12/15/2019  Times of India    0.874     0.000
# 1189  12/15/2019  Times of India    0.948     0.052
# 1190  12/15/2019  Times of India    0.922     0.078
# 1191  12/15/2019  Times of India    1.000     0.000
# 1192  12/15/2019  Times of India    0.881     0.000
# 1193  12/15/2019  Times of India    1.000     0.000
# 1194  12/15/2019  Times of India    1.000     0.000
# 1195  12/15/2019  Times of India    0.833     0.167
# 1196  12/15/2019  Times of India    0.803     0.197
# 1197  12/15/2019  Times of India    0.743     0.000
# 1198  12/15/2019  Times of India    1.000     0.000
# 1199  12/15/2019  Times of India    0.739     0.000
#
#                                                    Text  Tweet Polarity  \
# 0     RT @BBCSport: The BBC Sports Personality Coach...          0.0000
# 1     RT @BBCSport: The winner of the BBC Sports Per...          0.8074
# 2     RT @BBCSport: This year’s Helen Rollason award...          0.5994
# 3     RT @BBCSport: The BBC Sports Personality World...         -0.4215
# 4     RT @BBCSport: The winner of the BBC Sports Per...          0.9337
# 5     RT @BBCSport: Five minutes to go!\n\nThis is h...          0.0000
# 6     British man shot dead in robbery outside hotel...         -0.6486
# 7     Prince Louis: Earliest words inspired by TV co...          0.4939
# 8     RT @bbcweather: Our @BBCWthrWatchers have spot...          0.0000
# 9     RT @BBCSport: Tyson Fury has split from traine...         -0.5719
# 10    Faulty valve leaves thousands without water in...         -0.3182
# 11    RT @BBCWorld: Guymon was on its way to becomin...         -0.3182
# 12    Strictly Come Dancing: Final draws 11.3 millio...          0.0000
# 13    Sunday's headliner spot is no longer a Blank S...         -0.2960
# 14    "Thank you for the most amazing experience of ...          0.8655
# 15    RT @BBCWorld: The moment a bushfire spread acr...          0.0000
# 16    RT @BBCPolitics: "It's on me... I own this dis...         -0.0964
# 17    RT @BBCSport: China's state broadcaster has re...          0.0000
# 18    Ministers 'reviewing licence fee evasion sanct...          0.0000
# 19    RT @BBCPolitics: "You cannot hold Scotland in ...          0.0000
# 20    Starc-inspired Australia claim 296-run win ove...          0.5859
# 21    RT @BBCWorld: Botswana cancels hunters' licenc...         -0.7430
# 22    RT @BBCPolitics: General election 2019: Let th...         -0.3818
# 23    Stormzy says he's "tried to communicate" to Ma...          0.0000
# 24    RT @BBCPolitics: John McDonnell on the Labour ...          0.8176
# 25    RT @BBCPolitics: Shadow Chancellor John McDonn...         -0.4588
# 26    RT @BBCBreaking: 'A far cry from what science ...         -0.4767
# 27    RT @BBCSport: China's state broadcaster has re...          0.0000
# 28    'Remember our stillborn babies in Christmas ca...          0.0000
# 29    RT @BBCWorld: It's the first time in history t...         -0.5267
# ...                                                 ...             ...
# 1170  RT @toisports: #INDvWI | 1st ODI | WI win toss...          0.7717
# 1171  RT @toisports: #INDvWI | 1st ODI | WI win toss...          0.5859
# 1172  Girl raped, set ablaze in UP's Fatehpur \n\nRe...         -0.6808
# 1173  RT @toisports: #INDvWI | 1st ODI | Toss Update...          0.5859
# 1174  Passengers evacuate Qantas plane via emergency...         -0.3818
# 1175  Rs 30 lakh, five months of ‘hell’: Price of th...          0.2500
# 1176  #Mardaani2 and #JumanjiTheNextLevel see good g...          0.6705
# 1177  Delhi cocaine haul: Indonesian woman befriende...          0.0000
# 1178  Shooting at suburban Atlanta mall injures 1 as...          0.0000
# 1179  RT @toisports: #SachinTendulkar \n\n@sachin_rt...          0.0000
# 1180  How women are reclaiming the streets at night ...          0.5423
# 1181  Cocaine worth Rs 100 crore brought in for New ...          0.5574
# 1182  New Zealand recovery teams return to volcanic ...         -0.7269
# 1183  #JustIn \n\nSouthern Philippines hit by 6.9 ma...          0.0000
# 1184  7 things you didn’t know about urban crime in ...         -0.5423
# 1185  As per Guwahati Medical College Hospital, 3 pe...         -0.8896
# 1186  Did Hindu backlash cost Labour dear in UK elec...          0.3818
# 1187  RT @toisports: #PresidentsCup2019 \n\n@TigerWo...          0.5859
# 1188  How mothers are protecting wombs of disabled d...         -0.3818
# 1189  RT @toisports: #PAKvsSL\n\n1st Test, Day 5: Dh...          0.0516
# 1190  WATCH: You can't miss this clip of #RanbirKapo...          0.1139
# 1191  Onions make debt-ridden Karnataka farmer crore...          0.0000
# 1192  Protests against Citizenship (Amendment) Act i...         -0.2263
# 1193  Adopted by foreigners, they are now finding th...          0.0000
# 1194  RT @toisports: #PAKvsBAN\n\nCan't force player...          0.0000
# 1195  RT @toisports: .@RishabhPant17 needs patience ...          0.4215
# 1196  Prashant Kishor’s firm to support AAP in Delhi...          0.4019
# 1197  Yoga community has been very slow to respond t...         -0.7845
# 1198  30 Biggest smartphone launches of the year 201...          0.0000
# 1199  No more mobile pujas &amp; cricket: Data price...         -0.6486
#
#       Tweets Order
# 0              100
# 1               99
# 2               98
# 3               97
# 4               96
# 5               95
# 6               94
# 7               93
# 8               92
# 9               91
# 10              90
# 11              89
# 12              88
# 13              87
# 14              86
# 15              85
# 16              84
# 17              83
# 18              82
# 19              81
# 20              80
# 21              79
# 22              78
# 23              77
# 24              76
# 25              75
# 26              74
# 27              73
# 28              72
# 29              71
# ...            ...
# 1170           -70
# 1171           -71
# 1172           -72
# 1173           -73
# 1174           -74
# 1175           -75
# 1176           -76
# 1177           -77
# 1178           -78
# 1179           -79
# 1180           -80
# 1181           -81
# 1182           -82
# 1183           -83
# 1184           -84
# 1185           -85
# 1186           -86
# 1187           -87
# 1188           -88
# 1189           -89
# 1190           -90
# 1191           -91
# 1192           -92
# 1193           -93
# 1194           -94
# 1195           -95
# 1196           -96
# 1197           -97
# 1198           -98
# 1199           -99
#
# [1200 rows x 7 columns]

# %%
data['Text'].head()
# Out:
# 0    RT @BBCSport: The BBC Sports Personality Coach...
# 1    RT @BBCSport: The winner of the BBC Sports Per...
# 2    RT @BBCSport: This year’s Helen Rollason award...
# 3    RT @BBCSport: The BBC Sports Personality World...
# 4    RT @BBCSport: The winner of the BBC Sports Per...
# Name: Text, dtype: object

# %%
import re
for tweet in data['Text']:
    tweet = re.sub(r"^https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*$", " ", tweet)
    tweet = tweet.lower()
    tweet = re.sub(r"that's","that is",tweet)
    tweet = re.sub(r"there's","there is",tweet)
    tweet = re.sub(r"what's","what is",tweet)
    tweet = re.sub(r"where's","where is",tweet)
    tweet = re.sub(r"it's","it is",tweet)
    tweet = re.sub(r"who's","who is",tweet)
    tweet = re.sub(r"i'm","i am",tweet)
    tweet = re.sub(r"she's","she is",tweet)
    tweet = re.sub(r"he's","he is",tweet)
    tweet = re.sub(r"they're","they are",tweet)
    tweet = re.sub(r"who're","who are",tweet)
    tweet = re.sub(r"ain't","am not",tweet)
    tweet = re.sub(r"wouldn't","would not",tweet)
    tweet = re.sub(r"shouldn't","should not",tweet)
    tweet = re.sub(r"can't","can not",tweet)
    tweet = re.sub(r"couldn't","could not",tweet)
    tweet = re.sub(r"won't","will not",tweet)
    tweet = re.sub(r"\W"," ",tweet)
    tweet = re.sub(r"\d"," ",tweet)
    tweet = re.sub(r"\s+[a-z]\s+"," ",tweet)
    tweet = re.sub(r"\s+[a-z]$"," ",tweet)
    tweet = re.sub(r"^[a-z]\s+"," ",tweet)
    tweet = re.sub(r"\s+"," ",tweet)
    tweet = re.sub(r"rt ","",tweet)

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/shadaab17/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing. 
    text = text.replace('x', '')
#    text = re.sub(r'\W+', '', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwors from text
    return text
data['Text'] = data['Text'].apply(clean_text)

# %%
data['Text']
# Out:
# 0       rt bbcsport bbc sports personality coach year ...
# 1       rt bbcsport winner bbc sports personality life...
# 2       rt bbcsport years helen rollason award goes ma...
# 3       rt bbcsport bbc sports personality world sport...
# 4       rt bbcsport winner bbc sports personality unsu...
# 5       rt bbcsport five minutes gothis follow #spoty ...
# 6       british man shot dead robbery outside hotel bu...
# 7       prince louis earliest words inspired tv cook m...
# 8       rt bbcweather bbcwthrwatchers spotted large ha...
# 9       rt bbcsport tyson fury split trainer ben davis...
# 10      faulty valve leaves thousands without water be...
# 11      rt bbcworld guymon way becoming ghost town ope...
# 12      strictly come dancing final draws 113 million ...
# 13      sundays headliner spot longer blank space http...
# 14      thank amazing eperience lifethe winners strict...
# 15      rt bbcworld moment bushfire spread across tree...
# 16      rt bbcpolitics disastershadow chancellor john ...
# 17      rt bbcsport chinas state broadcaster reportedl...
# 18      ministers reviewing licence fee evasion sancti...
# 19      rt bbcpolitics cannot hold scotland union scot...
# 20      starcinspired australia claim 296run win new z...
# 21      rt bbcworld botswana cancels hunters licences ...
# 22      rt bbcpolitics general election 2019 let labou...
# 23      stormzy says hes tried communicate maya art ht...
# 24      rt bbcpolitics john mcdonnell labour leadershi...
# 25      rt bbcpolitics shadow chancellor john mcdonnel...
# 26      rt bbcbreaking far cry science tells us needed...
# 27      rt bbcsport chinas state broadcaster reportedl...
# 28      remember stillborn babies christmas cards http...
# 29      rt bbcworld first time history black women hol...
#                               ...
# 1170    rt toisports #indvwi 1st odi wi win toss opt b...
# 1171    rt toisports #indvwi 1st odi wi win toss opt b...
# 1172    girl raped set ablaze ups fatehpur read https ...
# 1173    rt toisports #indvwi 1st odi toss updatewest i...
# 1174    passengers evacuate qantas plane via emergency...
# 1175    rs 30 lakh five months hell price american dre...
# 1176    #mardaani2 #jumanjithenetlevel see good growth...
# 1177    delhi cocaine haul indonesian woman befriended...
# 1178    shooting suburban atlanta mall injures 1 shopp...
# 1179    rt toisports #sachintendulkar sachin_rt search...
# 1180    women reclaiming streets night indian women sa...
# 1181    cocaine worth rs 100 crore brought new year pa...
# 1182    new zealand recovery teams return volcanic isl...
# 1183    #justin southern philippines hit 69 magnitude ...
# 1184    7 things didnt know urban crime india bengalur...
# 1185    per guwahati medical college hospital 3 people...
# 1186    hindu backlash cost labour dear uk election re...
# 1187    rt toisports #presidentscup2019 tigerwoods lea...
# 1188    mothers protecting wombs disabled daughtersdis...
# 1189    rt toisports #pakvssl1st test day 5 dhananjaya...
# 1190    watch cant miss clip #ranbirkapoor #aliabhatt ...
# 1191    onions make debtridden karnataka farmer crorep...
# 1192    protests citizenship amendment act west bengal...
# 1193    adopted foreigners finding indian birth parent...
# 1194    rt toisports #pakvsbancant force players trave...
# 1195    rt toisports rishabhpant17 needs patience harn...
# 1196    prashant kishors firm support aap delhi polls ...
# 1197    yoga community slow respond problems seual abu...
# 1198    30 biggest smartphone launches year 2019 https...
# 1199    mobile pujas amp cricket data price pinches po...
# Name: Text, Length: 1200, dtype: object

# %%
for i in range(len(data)):
    data['Text'][i] = data['Text'][i].replace('rt ','')
# Out:
# /home/shadaab17/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['Text']
# Out:
# 0       bbcspobbc sports personality coach year 2019 j...
# 1       bbcspowinner bbc sports personality lifetime a...
# 2       bbcspoyears helen rollason award goes man show...
# 3       bbcspobbc sports personality world spostar yea...
# 4       bbcspowinner bbc sports personality unsung her...
# 5       bbcspofive minutes gothis follow #spoty across...
# 6       british man shot dead robbery outside hotel bu...
# 7       prince louis earliest words inspired tv cook m...
# 8       bbcweather bbcwthrwatchers spotted large hails...
# 9       bbcspotyson fury split trainer ben davison two...
# 10      faulty valve leaves thousands without water be...
# 11      bbcworld guymon way becoming ghost town openin...
# 12      strictly come dancing final draws 113 million ...
# 13      sundays headliner spot longer blank space http...
# 14      thank amazing eperience lifethe winners strict...
# 15      bbcworld moment bushfire spread across tree ca...
# 16      bbcpolitics disastershadow chancellor john mcd...
# 17      bbcspochinas state broadcaster reportedly pull...
# 18      ministers reviewing licence fee evasion sancti...
# 19      bbcpolitics cannot hold scotland union scotlan...
# 20      starcinspired australia claim 296run win new z...
# 21      bbcworld botswana cancels hunters licences kil...
# 22      bbcpolitics general election 2019 let labour l...
# 23      stormzy says hes tried communicate maya ahttps...
# 24      bbcpolitics john mcdonnell labour leadership r...
# 25      bbcpolitics shadow chancellor john mcdonnell d...
# 26      bbcbreaking far cry science tells us needed le...
# 27      bbcspochinas state broadcaster reportedly pull...
# 28      remember stillborn babies christmas cards http...
# 29      bbcworld first time history black women hold t...
#                               ...
# 1170    toisports #indvwi 1st odi wi win toss opt bowl...
# 1171    toisports #indvwi 1st odi wi win toss opt bowl...
# 1172    girl raped set ablaze ups fatehpur read https ...
# 1173    toisports #indvwi 1st odi toss updatewest indi...
# 1174    passengers evacuate qantas plane via emergency...
# 1175    rs 30 lakh five months hell price american dre...
# 1176    #mardaani2 #jumanjithenetlevel see good growth...
# 1177    delhi cocaine haul indonesian woman befriended...
# 1178    shooting suburban atlanta mall injures 1 shopp...
# 1179    toisports #sachintendulkar sachin_searching wa...
# 1180    women reclaiming streets night indian women sa...
# 1181    cocaine worth rs 100 crore brought new year pa...
# 1182    new zealand recovery teams return volcanic isl...
# 1183    #justin southern philippines hit 69 magnitude ...
# 1184    7 things didnt know urban crime india bengalur...
# 1185    per guwahati medical college hospital 3 people...
# 1186    hindu backlash cost labour dear uk election re...
# 1187    toisports #presidentscup2019 tigerwoods leads ...
# 1188    mothers protecting wombs disabled daughtersdis...
# 1189    toisports #pakvssl1st test day 5 dhananjaya de...
# 1190    watch cant miss clip #ranbirkapoor #aliabhatt ...
# 1191    onions make debtridden karnataka farmer crorep...
# 1192    protests citizenship amendment act west bengal...
# 1193    adopted foreigners finding indian birth parent...
# 1194    toisports #pakvsbancant force players travel p...
# 1195    toisports rishabhpant17 needs patience harness...
# 1196    prashant kishors firm suppoaap delhi polls rea...
# 1197    yoga community slow respond problems seual abu...
# 1198    30 biggest smartphone launches year 2019 https...
# 1199    mobile pujas amp cricket data price pinches po...
# Name: Text, Length: 1200, dtype: object

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='black',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
).generate(str(data))

    fig = plt.figure(1, figsize=(10, 10))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
show_wordcloud(data['Text'],'Most Common Words from the whole corpus')

# %%
#create lmplot using seasborn
#set colorlist for charts
clrlist = ["#82CAFA", "#438D80", "#FF0000", "#0000FF", "#FFFF00"]
sns.set_palette(clrlist)

#create chart
MediaTweetAnalysis=sns.lmplot(x="Tweets Order", y="Tweet Polarity", data= data, 
           hue="Media Sources",  size=10, aspect=1.4 ,
           legend_out = True, legend = False, 
           scatter_kws={"s":350, 
                        'alpha':.55,'edgecolors':"black", 'linewidth':1},ci=0, fit_reg=False, )

plt.xlim(102,-2)
plt.title("Sentiment Analysis of Media Tweets ("+str(table_dict["Date"][2])+")", fontsize=18)
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', ncol=1, title="Media Sources")
plt.savefig("Output/NSA_MediaTweets.png", bbox_inches='tight')
plt.show(MediaTweetAnalysis)
# Out:
# /home/shadaab17/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#create dataframe for using groupby
df = pd.DataFrame(data.groupby(["Media Sources"])["Tweet Polarity"].mean()).reset_index()
df
# Out:
#         Media Sources  Tweet Polarity
# 0       BBC News (UK)       -0.041601
# 1            CBS News       -0.058254
# 2                 CNN        0.002324
# 3            Fox News       -0.013781
# 4  The New York Times        0.056354
# 5      Times of India       -0.065792

# %%
#create barplot using seaborn
MediaSent_O=sns.barplot(x="Media Sources", y="Tweet Polarity", data=df)
plt.ylim(-.1,.1)
plt.ylabel('Tweet Polarity')
plt.title("Overall Media Sentiment based on Twitter ("+str(data["Date"][2])+")", fontsize=22)
plt.savefig("Output/NSA_OverallSentiment.png", bbox_inches='tight')
plt.show(MediaSent_O)

# %%
#export dataframe to csv file
data.to_csv('newsanalysis.csv', index=False)
